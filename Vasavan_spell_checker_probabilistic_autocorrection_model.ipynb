# %% [markdown]
# <a href="https://colab.research.google.com/github/Hari25483/Writing-Assistant-Tamil/blob/main/Vasavan_spell_checker_probabilistic_autocorrection_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import string
from collections import Counter
import numpy as np

# %%
import pandas as pd
import numpy as np
# import textdistance
# import re
from collections import Counter
import nltk
from nltk import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
word= []
with open('/content/quotes.txt', 'r') as f:
    file_name_data1 = f.read()
    # file_name_data=file_name_data.lower()
import re
# print(file_name_data1)
# file_name_data = re.sub(r'[^\w\s]', '', file_name_data1)

file_name_data1 =file_name_data1.replace('\n', '').replace('\r', '').replace('\ufeff', '').replace('“','').replace('”','').replace('.','').replace(',','').replace('[','').replace(']','')  #new line, carriage return, unicode character --> replace by space


word=word_tokenize(file_name_data1)

file = open("/content/stopwords_tamil", "r", encoding = "utf8")
tamil_stopwords=[]
for line in file:
  line=line.replace('\n', '')
  tamil_stopwords.append(line)

print(len(word))
for element in tamil_stopwords:
    if element in word:
          # print(element)
          word.remove(element)

print(len(word))

# stop_words = set(stopwords.words('english'))

# filtered_sentence = [w for w in word if not w.lower() in stop_words]
  
filtered_sentence = []
  
for w in word:
    if w not in tamil_stopwords:
        filtered_sentence.append(w)
  
print(word)
print(len(filtered_sentence))
# Out:
# 20592
# 20474
# ['இந்திய', 'வரலாறு', '(', 'History', 'of', 'India', ')', 'இந்தியத்', 'துணைக்கண்டத்தில்', 'வரலாற்றுக்', 'காலம்', 'முன்பு', 'வாழ்ந்த', 'மக்கள்', 'அவர்தம்', 'சமுதாயம்', 'சிந்து', 'சமவெளி', 'நாகரிகம்', 'இந்தோ-ஆரியப்', 'பண்பாடு', 'உள்ளடக்கிய', 'வேதகால', 'நாகரிகம்1', 'தொடங்கி', 'இன்றுவரை', 'காலம்', 'அடங்கும்', 'கலாச்சாரங்களின்', 'சாரமாகவும்', 'பண்பாடுகளை', 'உள்வாங்கியும்', 'பிறந்த', 'இந்து', 'சமயம்', 'வளர்ச்சி', 'குறித்தும்', 'சிரமணா', 'இயக்கத்தின்', 'வளர்ச்சி', 'சிரவுத்தா', 'பலிகளின்', 'வீழ்ச்சி', 'சைனம்', 'பௌத்தம்', 'சைவம்', 'வைணவம்', 'சக்தி', 'வழிபாடு', 'இவைகளின்', 'வளர்ச்சி', 'தாக்கம்23', 'மேலும்', 'இப்பகுதியில்', 'இரண்டாயிரம்', 'ஆண்டுகளாக', 'வாழ்ந்த', 'அரச', 'பரம்பரை', 'பேரரசுகளின்', 'தோற்றம்', 'தாக்கம்', 'இடைகாலத்தில்', 'தோன்றிய', 'இந்து', 'மற்றும்', 'முகலாய', 'அரச', 'பரம்பரைகள்', 'குறித்த', 'தகவல்கள்', 'பிற்காலத்தில்', 'ஐரோப்பிய', 'வணிகர்கள்', 'அதன்', 'தொடர்ச்சியாக', 'அமைந்த', 'ஆங்கிலேய', 'அரசு', 'அதன்', 'தொடர்ச்சியாக', 'எழுந்த', 'விடுதலை', 'இயக்கம்', 'அதன்', 'நாடு', 'பிரிவினை', 'அடைந்து', 'இந்தியக்', 'குடியரசு', 'பிறந்த', 'தகவல்கள்', 'உள்ளிட்டவை', 'அடங்கும்4சுமார்', '75000', 'ஆண்டுகளுக்கு', 'முன்பு', 'இந்திய', 'துணைக்கண்டத்தில்', 'இன்றைய', 'மனிதர்களின்', 'உடற்கூறியல்', 'வடிவத்தை', 'ஒத்த', 'மனிதர்களோ', '500000', 'ஆண்டுகளுக்கு', 'முன்பு', 'தற்கால', 'மனிதனின்', 'முன்னோடிகளோ', 'வாழ்ந்து', 'வந்ததற்கான', 'சான்றுகள்', 'பதிவு', 'செய்யப்பட்டுள்ளன5', 'கிமு', '3200', 'கிமு', '1300', 'வரை', 'இந்தியாவில்', 'செழிப்பாக', 'விளங்கிய', 'சிந்துவெளி', 'நாகரிகம்தான்', 'தெற்கு', 'ஆசியாவில்', '6', 'தோன்றிய', 'முதல்', 'நாகரிகம்', 'தொழில்', 'நுட்பத்திலும்', 'புதுமையிலும்', 'தலை', 'சிறந்த', 'மற்றும்', 'நகர்ப்புற', 'வாழ்க்கையில்', 'தனித்', 'தன்மை', 'வாய்ந்த', 'நாகரிகம்', 'பயன்பாட்டில்', 'இருந்த', 'காரப்பா', 'காலம்7', 'கிமு', '2600', 'முதல்', 'கிமு', '1900', 'வரை', 'தொடர்ந்தது', 'கிமு', 'இரண்டாவது', 'ஆயிரமாண்டு', 'துவக்கத்தில்', 'மறைய', 'தொடர்ச்சியாக', 'இரும்புக்கால', 'வேதிய', 'நாகரிகம்', 'சிந்து-கங்கைச்', 'சமவெளியில்', 'தோன்றி', 'வளர்ந்தது', 'இக்காலத்தில்', 'மகாசனப்பாடங்கள்', 'பல', 'அரசாட்சிமுறைகளும்', 'தோன்றி', 'வளர்ந்தன', 'கிமு', '5-ஆம்', 'நூற்றாண்டு', 'முதல்', 'கிமு', '6-ஆம்', 'நூற்றாண்டு', 'வாக்கில்', 'இது', 'அரச', 'வம்சத்தில்', 'தான்', 'மகதர்கள்', 'மகாவீரர்', 'கௌதம', 'புத்தர்', 'போன்றோர்', 'தோன்றி', '’', '’', 'சிராமனிய', '’', '’', 'தத்துவத்தைப்', 'பரப்பி', 'வந்தனர்கிமு', '4', 'ஆம்', 'நூற்றாண்டு', 'மற்றும்', 'கிமு', '3', 'ஆம்', 'நூற்றாண்டுகளில்', 'துணைக்கண்டத்தின்', 'பகுதி', 'மவுரியப்', 'பேரரசின்', 'கீழ்', 'கொண்டுவரப்பட்டது', 'இக்கால', 'கட்டத்தில்', 'வடநாட்டில்', 'பிரகிருதி', 'மற்றும்', 'பாளி', 'மொழி', 'இலக்கியங்களும்', 'தெற்கில்', 'சங்க', 'இலக்கியங்களும்', 'வளர்ச்சியடைந்தன89', 'தென்னிந்தியாவில்', 'எடுக்கப்பட்ட', 'ஊட்டுச்சு', 'எக்கு101112', 'ஒரு', 'வகை', 'இரும்பு', 'இக்காலத்தில்', 'வெளிநாடுகளுக்கு', 'ஏற்றுமதி', 'செய்யப்பட்டது', '1500', 'ஆண்டுகள்', 'இந்தியாவின்', 'பல', 'பகுதிகள்', 'பல', 'அரசர்களால்', 'ஆளப்பட்டிருந்தாலும்', 'இக்காலத்தில்', 'குப்தர்', 'ஆண்ட', 'காலம்', 'தனிச்', 'சிறப்பு', 'வாய்ந்ததாக', 'அமைந்தது', 'இந்து', 'சமயமும்', 'கலை', 'கலாச்சாரம்', 'போன்றவையும்', 'புத்தாக்கம்', 'பெற்று', 'மறுமலர்ச்சியடைந்து', 'விளங்கியதால்', 'இந்தியாவின்', 'பொற்காலம்', 'குப்தர்களின்', 'காலம்', 'வர்ணிக்கப்படுகிறதுஇக்காலத்தில்', 'இந்திய', 'நாகரிகம்', 'கலை', 'கலாச்சாரம்', 'பண்பாடு', 'குறிப்பாக', 'இந்து', 'சமயம்', 'மற்றும்', 'பௌத்தம்', 'முதலியன', 'ஆசியா', 'முழுவதும்', 'பரவின', 'கிமு', '77-ஆம்', 'ஆண்டு', 'வாக்கில்', 'தென்னிந்திய', 'அரசுகள்', 'உரோமப்', 'பேரரசுடன்', 'தொடர்பு', 'வைத்திருந்தன', 'இந்திய', 'கலாச்சாரத்தின்', 'தாக்கமும்', 'வீச்சமும்', 'தென்கிழக்காசியாவின்', 'பல', 'இடங்களில்', 'பரவின', 'இதன்', 'காரணமாக', 'பல', 'இந்திய', 'வம்சாவளி', 'அரசுகள்1314', 'இப்பகுதியில்', 'அமைந்தனபாலி', 'இராசிட்ரகூடம்', 'குருசார', 'பிராதிகார', 'பேரரசு', 'ஆகியவற்றிடையே', 'கன்னோசி', 'அரசை', 'மையப்படுத்தி', 'நடந்த', 'மும்முனைப்', 'போட்டி', 'கிபி', '7-ஆம்', 'நூற்றாண்டிற்கும்', '11-ஆம்', 'நூற்றாண்டிற்கும்', 'இடைப்பட்ட', 'காலத்தில்', 'நடந்த', 'முக்கியமான', 'நிகழ்வாகும்', 'இப்போராட்டம்', 'இரண்டு', 'நூற்றாண்டுகளாகத்', 'தொடர்ந்தது', 'தென்னிந்தியா', 'அப்பொழுது', 'சாளுக்கியர்', 'சோழர்', 'பல்லவர்' ...
# 18317

# %%
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("/content/quotes.txt")
print(word)
print(f"There are {len(words)} total words in the corpus")
# Out:
# ['இந்திய', 'வரலாறு', '(', 'History', 'of', 'India', ')', 'இந்தியத்', 'துணைக்கண்டத்தில்', 'வரலாற்றுக்', 'காலம்', 'முன்பு', 'வாழ்ந்த', 'மக்கள்', 'அவர்தம்', 'சமுதாயம்', 'சிந்து', 'சமவெளி', 'நாகரிகம்', 'இந்தோ-ஆரியப்', 'பண்பாடு', 'உள்ளடக்கிய', 'வேதகால', 'நாகரிகம்1', 'தொடங்கி', 'இன்றுவரை', 'காலம்', 'அடங்கும்', 'கலாச்சாரங்களின்', 'சாரமாகவும்', 'பண்பாடுகளை', 'உள்வாங்கியும்', 'பிறந்த', 'இந்து', 'சமயம்', 'வளர்ச்சி', 'குறித்தும்', 'சிரமணா', 'இயக்கத்தின்', 'வளர்ச்சி', 'சிரவுத்தா', 'பலிகளின்', 'வீழ்ச்சி', 'சைனம்', 'பௌத்தம்', 'சைவம்', 'வைணவம்', 'சக்தி', 'வழிபாடு', 'இவைகளின்', 'வளர்ச்சி', 'தாக்கம்23', 'மேலும்', 'இப்பகுதியில்', 'இரண்டாயிரம்', 'ஆண்டுகளாக', 'வாழ்ந்த', 'அரச', 'பரம்பரை', 'பேரரசுகளின்', 'தோற்றம்', 'தாக்கம்', 'இடைகாலத்தில்', 'தோன்றிய', 'இந்து', 'மற்றும்', 'முகலாய', 'அரச', 'பரம்பரைகள்', 'குறித்த', 'தகவல்கள்', 'பிற்காலத்தில்', 'ஐரோப்பிய', 'வணிகர்கள்', 'அதன்', 'தொடர்ச்சியாக', 'அமைந்த', 'ஆங்கிலேய', 'அரசு', 'அதன்', 'தொடர்ச்சியாக', 'எழுந்த', 'விடுதலை', 'இயக்கம்', 'அதன்', 'நாடு', 'பிரிவினை', 'அடைந்து', 'இந்தியக்', 'குடியரசு', 'பிறந்த', 'தகவல்கள்', 'உள்ளிட்டவை', 'அடங்கும்4சுமார்', '75000', 'ஆண்டுகளுக்கு', 'முன்பு', 'இந்திய', 'துணைக்கண்டத்தில்', 'இன்றைய', 'மனிதர்களின்', 'உடற்கூறியல்', 'வடிவத்தை', 'ஒத்த', 'மனிதர்களோ', '500000', 'ஆண்டுகளுக்கு', 'முன்பு', 'தற்கால', 'மனிதனின்', 'முன்னோடிகளோ', 'வாழ்ந்து', 'வந்ததற்கான', 'சான்றுகள்', 'பதிவு', 'செய்யப்பட்டுள்ளன5', 'கிமு', '3200', 'கிமு', '1300', 'வரை', 'இந்தியாவில்', 'செழிப்பாக', 'விளங்கிய', 'சிந்துவெளி', 'நாகரிகம்தான்', 'தெற்கு', 'ஆசியாவில்', '6', 'தோன்றிய', 'முதல்', 'நாகரிகம்', 'தொழில்', 'நுட்பத்திலும்', 'புதுமையிலும்', 'தலை', 'சிறந்த', 'மற்றும்', 'நகர்ப்புற', 'வாழ்க்கையில்', 'தனித்', 'தன்மை', 'வாய்ந்த', 'நாகரிகம்', 'பயன்பாட்டில்', 'இருந்த', 'காரப்பா', 'காலம்7', 'கிமு', '2600', 'முதல்', 'கிமு', '1900', 'வரை', 'தொடர்ந்தது', 'கிமு', 'இரண்டாவது', 'ஆயிரமாண்டு', 'துவக்கத்தில்', 'மறைய', 'தொடர்ச்சியாக', 'இரும்புக்கால', 'வேதிய', 'நாகரிகம்', 'சிந்து-கங்கைச்', 'சமவெளியில்', 'தோன்றி', 'வளர்ந்தது', 'இக்காலத்தில்', 'மகாசனப்பாடங்கள்', 'பல', 'அரசாட்சிமுறைகளும்', 'தோன்றி', 'வளர்ந்தன', 'கிமு', '5-ஆம்', 'நூற்றாண்டு', 'முதல்', 'கிமு', '6-ஆம்', 'நூற்றாண்டு', 'வாக்கில்', 'இது', 'அரச', 'வம்சத்தில்', 'தான்', 'மகதர்கள்', 'மகாவீரர்', 'கௌதம', 'புத்தர்', 'போன்றோர்', 'தோன்றி', '’', '’', 'சிராமனிய', '’', '’', 'தத்துவத்தைப்', 'பரப்பி', 'வந்தனர்கிமு', '4', 'ஆம்', 'நூற்றாண்டு', 'மற்றும்', 'கிமு', '3', 'ஆம்', 'நூற்றாண்டுகளில்', 'துணைக்கண்டத்தின்', 'பகுதி', 'மவுரியப்', 'பேரரசின்', 'கீழ்', 'கொண்டுவரப்பட்டது', 'இக்கால', 'கட்டத்தில்', 'வடநாட்டில்', 'பிரகிருதி', 'மற்றும்', 'பாளி', 'மொழி', 'இலக்கியங்களும்', 'தெற்கில்', 'சங்க', 'இலக்கியங்களும்', 'வளர்ச்சியடைந்தன89', 'தென்னிந்தியாவில்', 'எடுக்கப்பட்ட', 'ஊட்டுச்சு', 'எக்கு101112', 'ஒரு', 'வகை', 'இரும்பு', 'இக்காலத்தில்', 'வெளிநாடுகளுக்கு', 'ஏற்றுமதி', 'செய்யப்பட்டது', '1500', 'ஆண்டுகள்', 'இந்தியாவின்', 'பல', 'பகுதிகள்', 'பல', 'அரசர்களால்', 'ஆளப்பட்டிருந்தாலும்', 'இக்காலத்தில்', 'குப்தர்', 'ஆண்ட', 'காலம்', 'தனிச்', 'சிறப்பு', 'வாய்ந்ததாக', 'அமைந்தது', 'இந்து', 'சமயமும்', 'கலை', 'கலாச்சாரம்', 'போன்றவையும்', 'புத்தாக்கம்', 'பெற்று', 'மறுமலர்ச்சியடைந்து', 'விளங்கியதால்', 'இந்தியாவின்', 'பொற்காலம்', 'குப்தர்களின்', 'காலம்', 'வர்ணிக்கப்படுகிறதுஇக்காலத்தில்', 'இந்திய', 'நாகரிகம்', 'கலை', 'கலாச்சாரம்', 'பண்பாடு', 'குறிப்பாக', 'இந்து', 'சமயம்', 'மற்றும்', 'பௌத்தம்', 'முதலியன', 'ஆசியா', 'முழுவதும்', 'பரவின', 'கிமு', '77-ஆம்', 'ஆண்டு', 'வாக்கில்', 'தென்னிந்திய', 'அரசுகள்', 'உரோமப்', 'பேரரசுடன்', 'தொடர்பு', 'வைத்திருந்தன', 'இந்திய', 'கலாச்சாரத்தின்', 'தாக்கமும்', 'வீச்சமும்', 'தென்கிழக்காசியாவின்', 'பல', 'இடங்களில்', 'பரவின', 'இதன்', 'காரணமாக', 'பல', 'இந்திய', 'வம்சாவளி', 'அரசுகள்1314', 'இப்பகுதியில்', 'அமைந்தனபாலி', 'இராசிட்ரகூடம்', 'குருசார', 'பிராதிகார', 'பேரரசு', 'ஆகியவற்றிடையே', 'கன்னோசி', 'அரசை', 'மையப்படுத்தி', 'நடந்த', 'மும்முனைப்', 'போட்டி', 'கிபி', '7-ஆம்', 'நூற்றாண்டிற்கும்', '11-ஆம்', 'நூற்றாண்டிற்கும்', 'இடைப்பட்ட', 'காலத்தில்', 'நடந்த', 'முக்கியமான', 'நிகழ்வாகும்', 'இப்போராட்டம்', 'இரண்டு', 'நூற்றாண்டுகளாகத்', 'தொடர்ந்தது', 'தென்னிந்தியா', 'அப்பொழுது', 'சாளுக்கியர்', 'சோழர்', 'பல்லவர்' ...
# There are 100352 total words in the corpus

# %%
vocabs = set(word)
print(vocabs)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# {'மாற்றி', 'பிரசினைகளை', 'திருத்தப்படலாம்', 'விளங்கியது28', 'முயற்சி', 'சிவப்பு', 'போன்றவை', 'மலாயா', 'ஆப்பிரிக்க', 'வரலாற்றைக்', 'நிற', '1236–1240', 'அறிஞர்களினதும்', 'மனப்பான்மையை', 'இயற்றப்பட்டது', 'தலைநகரமான', 'கூட்டுமெய்களும்', 'கோல்டிங்சு', 'அமைச்சின்', 'கிர்கிசுத்தான்துசான்பே', 'வந்ததுஇலங்கையின்', 'மறுமலர்ச்சி', 'புகிட்', 'மிதவெப்ப', 'ஒன்றாகும்60முகலாய', 'மகனுமான', 'அமைப்புகளுக்கு', 'அடைந்தான்26', 'லம்பகண்ண', '1674–1820', '1070–1230', 'அல்லது', 'சேர்ந்து', 'முகமது', 'வீசுவதோடு', 'சீனாவுக்குச்', 'பரந்தும்', 'திணைக்களங்கள்', 'கப்பல்களைக்', 'பிரகிருதி', 'கருதியது173', 'அரசாங்கத்துக்கும்', 'பேரரசன்', 'பஞ்சங்களும்', '1450', 'மாற்றமும்', 'எச்சரிக்கையை', 'கைப்பற்றினார்', 'இவர்களின்', 'கணித', 'பிளினி', 'அனுப்பப்பட்டனர்116', 'ஆக்கிரமிக்கப்பட்ட', 'தன்மை', 'வகிக்கின்றன', 'தென்மேற்கு', 'இஸ்லாமிய', 'சமற்கிருதம்', 'தொல்லெழுத்துப்', 'வழக்குகளின்', 'ராசகாரிய', 'ஆசியாவிலே', 'காணொளிமூலம்', 'பொற்காலத்தின்', 'வலிமையாக', 'இலவசமாக', 'எண்களும்', 'யுனெசுக்கோவினால்', 'பெற்றவராகக்', 'இத்தடை', 'தொடரைச்', '63', 'எறும்பு', 'ஏற', 'இலங்கையைக்', 'சேர்த்தன', 'பெரும்பாலான', 'பகுதிகளைக்', 'பொது', 'உருலு', 'இந்தோ-பார்த்தியர்கள்', 'தமிழருக்குமிடையே', 'சிலவாகும்இலங்கையரின்', 'இயல்பாகத்', 'டட்லி', 'தத்துவ', 'முள்ளம்பன்றிகள்', 'செய்கின்றனர்', 'போர்த்துகீசர்', 'Singapura', 'தோற்றுவித்தவனாகக்', 'தர்சீசுவாக', 'ஏற்றுவதை', 'ராஜபுதர்கள்', 'போர்த்துக்கீசருடனான', 'துறைக்கான', 'தாகபைகள்', 'சொற்களான', 'நிகழ்ந்தது', 'வேறுபடுத்துவதில்லை', 'ஒன்றுபடுத்தியது', 'அரசுகரும', 'சேர்த்தார்', 'ஒலிப்புமுறை', 'வெளிநாடுகளில்', 'கொள்கைகளால்இந்தியாவில்', 'உழைத்தனர்', 'கொள்கின்றன', 'அகதிகள்', '1960ல்', 'பகுதிகளாகப்', 'தொகை', 'தொலைக்காட்சி', '562', 'மையப்படுத்தி', 'கொண்டது27', 'படித்தவர்', 'அவையில்', 'பணிப்பெண்ணொருத்திக்கும்', 'எழுத்திற்கு', 'முன்னணி', 'சிரமப்படுபவர்களுக்கு', 'அமைகிறது', 'யாப்பை', 'அடைப்படையிலும்', 'ஒத்துள்ளதுதமிழ்', 'இத்தகைய', 'மொழிகளிலும்', '1974ல்', 'தடகள', '1003–1320', '10', '1959-ஆம்', 'படை', 'கைப்பற்றிய', 'இப்பகுதியில்', 'வானூர்தி', 'தேவைப்படவில்லை', 'அடையாளத்துடன்', 'பின்பற்றுவதுடன்', '7019', 'நெரிச்சல்', 'வான்புகழ்', 'இருக்கவில்லை', 'செயற்படுகிறது186', 'மதத்தைத்', "'அடர்", 'தோன்றுவதற்குக்', 'தேர்ந்தெடுக்கப்பட்டார்134', 'படுகொலை', 'கலைகள்', 'வளர்ச்சியடைந்தன89', 'ஒலிம்பிக்கில்', 'சிறுபான்மை', 'பயன்படும்', 'அரசினால்', 'மீற்றருக்கும்', 'போன்ற', 'வணிகப்', 'கூலித்', 'பள்ளீகளையும்', 'செய்யப்பட', 'இந்தியாவைச்சேர்ந்த', 'சாம்ராஜ்ஜியத்தைப்போல', 'மதங்களும்', 'அறியப்படுகிறது', 'மலைநாட்டில்', 'விபீடணனை', 'டில்லியில்', 'கொள்கையின்', '35சூரதீச', 'குப்தப்', 'ஆகியனவாகப்', 'அனுப்பிவைக்கப்பட்டுள்ளதுடன்', 'மகாராட்டிரத்தில்', 'யானைகளின்', 'இரண்டிற்கும்', 'பம்பரகந்த', 'திருப்பி', 'கேரளாவிலும்', 'ஆசுதிரேலிய', 'பெருமளவுக்கு', 'பெருமக்கள்', '22சிங்கப்பூர்', 'பயனோக்கு', 'ப்ரதிஹாரா', 'அசைச்சொற்களையும்', 'ராசாதிராசசிங்கன்', 'இக்கருத்திலிருந்து', 'தேவநம்பிய', 'மதம்', 'ராவணனிடம்', 'வில்கின்ஸ்', 'மட்டத்திலிருந்து', 'கற்பனையா', 'ஸ்ட்ராபோ', 'மாகாணங்களிலும்', 'மறைவுக்கு', 'பயணிகளுக்கு', 'கொள்ளப்படுகிறதுதென்னிந்தியாவில்', 'இளவரசர்', 'மனைவி', 'ஆ', 'மில்', 'இலங்கைக்கு', 'முடிந்தன', 'தத்துவங்களில்', 'இணைத்துக்', 'எழுதப்பட்டதாகவே', 'அஸ்ஸாம்', 'குறிப்பிடத்தக்க', 'காணப்படும்', 'மொழிக்கு', 'போக்குவரத்து', 'குடும்பத்தைச்', 'வருடத்துக்கு', '50-50', 'காலத்திற்கு', 'பிரிக்கப்பட்டுள்ளது166', 'காணப்படுவதோடு', 'இறந்தனர்73', 'பிரதமர்', 'வங்காளத்தில்', 'இருந்தனஆங்கில', 'கூறுகின்றனர்தமிழை', 'அறிந்திருந்தது', 'வரலாற்றைச்', 'பின்பற்றி', 'தாக்கம்', 'சனாதிபதி', 'வட-கிழக்கு', 'கோதுமையுமே', 'ஆழ்வார்', 'நகரமாகக்', 'சீதா', 'அவ்வளவு', 'இருபதாம்', 'கருணைகாட்டுதல்', 'செய்கிறார்', 'இரண்டாண்டுகளுக்குப்', 'நாட்டின்', 'எதிர்', 'பயன்பாட்டிலுள்ளது', 'குறைந்தது', 'கருவேல', 'வந்ததால்', 'மனம்', 'கர்னல்', 'பெலிலென', 'கவுத்தமர்', 'சிறார்களுக்குக்', '19', 'தற்காலப்', 'தேடி', '9சிங்கப்பூர்', 'பல்லவர்', 'எசுபிஎசு', '17சிங்கப்பூர்', 'பாஜி', '°F', 'கூறுகின்றபோதும்', 'சமயத்தைப்', '3-ஆம்', 'கருங்காலி', 'அரேபியாசனா', 'தீர்மானித்த', 'சாதவாகனர்களின்', 'அதிரடிப்படையினர்', 'பௌத்தத்தை', 'பதக்கங்கள்', 'பாரசீகத்தின்', 'நடுப்பகுதியில்', 'ஏதுமில்லாதிருந்த', 'வழங்குவதுமான', 'துணை', 'பெயராகும்', 'ஆகும்21சௌத்துவருத்து', 'ஒன்றுக்கு', 'பேசக்கூடியவர்களாகவும்' ...
# There are 9224 unique words in the vocabulary

# %%
words=word
word_counts = Counter(words)
print(word_counts["இந்திய"])
# Out:
# 101

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["இந்திய"])
# Out:
# 0.0049330858649995115

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'tkrash', 'txrash', 'trasl', 'traih', 'trrash', 'traoh', 'trasdh', 'trajh', 'tkash', 'trgash', 'toash', 'trrsh', 'twrash', 'mrash', 'tjrash', 'tsrash', 'triash', 'tdrash', 'tarsh', 'trmash', 'traesh', 'tratsh', 'tiash', 'trapsh', 'trafh', 'tpash', 'twash', 'tramsh', 'trmsh', 'trashy', 'tzrash', 'trdash', 'trxash', 'trafsh', 'trish', 'tras', 'tfrash', 'trlsh', 'ktrash', 'truash', 'trfsh', 'rtrash', 'ltrash', 'trwash', 'tresh', 'orash', 'jrash', 'tbrash', 'traso', 'trass', 'trassh', 'trasg', 'trasm', 'trasah', 'tash', 'tradsh', 'trasph', 'trashq', 'rrash', 'tvrash', 'trcash', 'trasw', 'trysh', 'trosh', 'trahsh', 'trcsh', 'trasrh', 'trssh', 'traash', 'tranh', 'trakh', 'drash', 'trgsh', 'trashg', 'trahs', 'trasc', 'tramh', 'trasxh', 'wtrash', 'tracsh', 'trazh', 'trashc', 'itrash', 'trashr', 'tyash', 'trksh', 'trlash', 'trtsh', 'trwsh', 'trasho', 'travsh', 'ctrash', 'atrash', 'traush', 'trasj', 'trvsh', 'btrash', 'traysh', 'arash', 'xtrash', 'rash', 'trashp', 'mtrash', 'trasht', 'trashv', 'zrash', 'traslh', 'trashe', 'terash', 'brash', 'tlash', 'strash', 'trasnh', 'trbsh', 'trasy', 'tcash', 'trashs', 'utrash', 'gtrash', 'nrash', 'trsh', 'grash', 'trashw', 'trahh', 'traksh', 'trashb', 'trpash', 'thrash', 'tirash', 'trasd', 'trxsh', 'trasi', 'trsash', 'tmrash', 'dtrash', 'trashh', 'traskh', 'tcrash', 'trauh', 'traqh', 'tbash', 'traxsh', 'ptrash', 'trashi', 'trase', 'tyrash', 'trasch', 'trjash', 'trzsh', 'trqsh', 'ttash', 'traph', 'trasx', 'ttrash', 'trarh', 'srash', 'traqsh', 'tjash', 'traswh', 'tralh', 'travh', 'trabh', 'trasf', 'trush', 'etrash', 'treash', 'trtash', 'trasbh', 'traah', 'xrash', 'trashf', 'tragsh', 'tnrash', 'trkash', 'trash', 'otrash', 'tgrash', 'trjsh', 'yrash', 'trasth', 'tnash', 'traszh', 'vrash', 'trqash', 'frash', 'trpsh', 'trasih', 'trvash', 'trawsh', 'trasha', 'trazsh', 'tzash', 'ytrash', 'trbash', 'teash', 'trawh', 'trasq', 'trashz', 'trasuh', 'lrash', 'traxh', 'taash', 'trask', 'trasvh', 'trhsh', 'tvash', 'trnsh', 'tragh', 'trast', 'krash', 'urash', 'trasjh', 'trasa', 'tarash', 'trasp', 'trasv', 'trashu', 'ftrash', 'trashk', 'torash', 'trnash', 'trasmh', 'transh', 'traeh', 'prash', 'tlrash', 'trfash', 'trzash', 'tralsh', 'traseh', 'ztrash', 'tqrash', 'trasz', 'htrash', 'turash', 'troash', 'txash', 'traosh', 'trashm', 'hrash', 'trach', 'rtash', 'ntrash', 'trasu', 'trasfh', 'trashd', 'qtrash', 'trasb', 'tgash', 'trsah', 'trasoh', 'crash', 'trath', 'tryash', 'tdash', 'trasgh', 'trhash', 'tmash', 'trabsh', 'traish', 'vtrash', 'qrash', 'trasr', 'trasqh', 'irash', 'trah', 'wrash', 'trayh', 'trasn', 'tprash', 'trarsh', 'trdsh', 'tsash', 'trashn', 'tradh', 'tqash', 'tfash', 'thash', 'trashl', 'erash', 'trasyh', 'trashx', 'jtrash', 'trashj', 'trajsh', 'tuash'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("trash"))
# Out:
# {'ctrcsh', 'traschz', 'trfsu', 'kgtrash', 'trusx', 'itirash', 'taaah', 'raqsh', 'trysnh', 'trns', 'nrasj', 'rtasz', 'tnkash', 'nrashb', 'rtrashk', 'trakn', 'mruash', 'triaeh', 'tfashc', 'trhslh', 'ktraesh', 'traqbh', 'tranlsh', 'trasdah', 'tnrast', 'trtauh', 'traysj', 'pftrash', 'txpsh', 'tratshf', 'tzrysh', 'ktfash', 'drazsh', 'rashm', 'trased', 'tgrxsh', 'trasehh', 'tagrash', 'trrasmh', 'tsawh', 'trasxhf', 'tsasf', 'fhash', 'trvaish', 'grasn', 'tlasa', 'tqrwsh', 'tpahsh', 'rtorash', 'tqfrash', 'tuasp', 'hirash', 'trxaah', 'ttaxh', 'trrasuh', 'trrszh', 'marsh', 'trasce', 'sraysh', 'ithrash', 'trmajh', 'mralh', 'otrashl', 'trasuqh', 'srfsh', 'trjafh', 'trashxb', 'tpyrash', 'ftrsash', 'prasih', 'cvtrash', 'ftramsh', 'orabh', 'toerash', 'lramh', 'trashgm', 'trpish', 'fgtrash', 'hraqh', 'ftradh', 'tjrasf', 'qramh', 'tyajh', 'tmcrash', 'trasmih', 'rrjash', 'ziash', 'qtcash', 'trsxah', 'tpvrash', 'dtrasw', 'lrjash', 'tracn', 'tprahs', 'tlashn', 'taprash', 'tnras', 'terdash', 'toasch', 'tlasc', 'truzash', 'etrsh', 'tkasgh', 'xtravsh', 'zltrash', 'tnashq', 'xras', 'tuiash', 'tranhv', 'travszh', 'tdaswh', 'nrgash', 'tdasdh', 'tryjash', 'tjasqh', 'trarse', 'trtosh', 'trasohx', 'sraslh', 'ktravsh', 'thasha', 'tralqsh', 'trfmsh', 'etrast', 'tqashe', 'wqash', 'trrast', 'tvhrash', 'ptrapsh', 'htdash', 'tsrashl', 'trajk', 'tregash', 'towsh', 'trcasph', 'tsavsh', 'taaash', 'trtaah', 'drysh', 'tyalh', 'tarasah', 'nrach', 'trssy', 'hlash', 'trsshw', 'trbeh', 'hrashx', 'tfashx', 'trqashf', 'tralmsh', 'wtrashj', 'vrasm', 'srasph', 'wtraysh', 'ttashh', 'ppash', 'tarssh', 'trazsjh', 'trasqwh', 'prssh', 'jsash', 'sraskh', 'traesg', 'trksk', 'tlaish', 'turrsh', 'trashbd', 'twraseh', 'taraih', 'traet', 'rxsh', 'qrjash', 'tgadh', 'traqu', 'torush', 'xrashz', 'tvasfh', 'trjzsh', 'yroash', 'trzrsh', 'lyrash', 'jmrash', 'gtrmash', 'trmaslh', 'terasp', 'trbshv', 'tradsmh', 'trkkash', 'orashy', 'htruash', 'trisfh', 'atrasn', 'trasud', 'trasfwh', 'trausa', 'tuarh', 'traysdh', 'xtrajsh', 'tuasah', 'gmtrash', 'tprasc', 'ptrbsh', 'twrasn', 'atarash', 'tarsih', 'trasf', 'trashbq', 'timsh', 'gtrass', 'cras', 'oratsh', 'traxso', 'trtasw', 'traqjsh', 'ramsh', 'trmasz', 'tewash', 'trsaqh', 'tprtash', 'traysqh', 'drvsh', 'trapss', 'drsh', 'tramz', 'jvrash', 'trazslh', 'trgsb', 'tjrahs', 'tranhh', 'htraslh', 'trahsuh', 'trasfxh', 'tfrauh', 'tfasr', 'tsasy', 'tmas', 'jtfrash', 'rtasxh', 'xtrashb', 'wrast', 'teroash', 'ttvrash', 'trqasw', 'trishv', 'trav', 'trjasyh', 'trsask', 'tragshl', 'orcsh', 'travshh', 'trasnth', 'troasih', 'trajg', 'tkish', 'tradsq', 'aetrash', 'hrwsh', 'vrasw', 'tfasxh', 'utraesh', 'travnh', 'htrashv', 'trpshn', 'trasbz', 'trafpsh', 'erashz', 'trouh', 'trxsl', 'trjawh', 'traslu', 'ptrhash', 'trashxz', 'trashrq', 'torasn', 'trsasv', 'tuatsh', 'tlrzsh', 'traxshy', 'tbrasn', 'tsrqash', 'trmasha', 'trrasa', 'aradsh', 'tqcsh', 'trasshv', 'trasihw', 'hthash', 'otrasf', 'yraxsh', 'turvash', 'traslr', 'ftravsh', 'urasha', 'tracf', 'trrss', 'tracshn', 'trcss', 'twraszh', 'tqaswh', 'trqamsh', 'zrmash', 'tjrazsh', 'wtrbsh', 'lsrash', 'stranh', 'trastf', 'tgasmh', 'trms', 'trywh', 'ttdrash', 'arzsh', 'gtrxsh', 'trajshk', 'trzshi', 'tryzash', 'tuasfh', 'trgmash', 'trnashs', 'tfrashl', 'htrawsh', 'trrahh', 'vtrauh', 'trnasyh', 'trzsgh', 'tgrashc', 'frasw', 'tnrfash', 'trauh', 'crtrash', 'graso', 'krasi', 'tqaish', 'ttrass', 'trqqash', 'urasht', 'trasaeh', 'traxush', 'trrslh', 'tezsh', 'tlasah', 'tfrxash', 'etrasqh', 'trcamsh', 'utraso', 'ntrasx', 'tqsh', 'wrasz', 'trtasp', 'trasri', 'trnish', 'tjasgh', 'fstrash', 'toasx', 'tfhsh', 'terarsh', 'grahh', 'ctroash', 'trasigh', 'ktzrash', 'jravh', 'trasq', 'trjh', 'wrjash', 'trmaseh', 'tkprash', 'ktraslh', 'traoshu', 'traddsh', 'eraswh', 'tyrcsh', 'rrfsh', 'tbatsh', 'thbrash', 'txawh', 'orasq', 'truasq', 'trasthi', 'trakhl', 'tcrish', 'trqasjh', 'trvashy', 'tsnrash', 'wtrasd', 'trauhd', 'trgacsh', 'ltrrsh', 'etraph', 'trrshp', 'traaeh', 'tralsuh', 'trdxh', 'vtrach', 'traspha', 'trnaslh', 'vrfash', 'trasel', 'terash ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "famile"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r") as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters] 

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("/content/quotes.txt")

# %%
checker.check("இந்திய")
# Out:
# []
