# %% [markdown]
# <a href="https://colab.research.google.com/github/Hari25483/Writing-Assistant-Tamil/blob/main/Praveen_Anna_Grammar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install happytransformer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting happytransformer
#   Downloading happytransformer-2.4.1-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 1.9 MB/s
# Requirement already satisfied: torch>=1.0 in /usr/local/lib/python3.7/dist-packages (from happytransformer) (1.12.1+cu113)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 9.0 MB/s
# Requirement already satisfied: tqdm>=4.43 in /usr/local/lib/python3.7/dist-packages (from happytransformer) (4.64.1)
# Collecting datasets>=1.6.0
#   Downloading datasets-2.5.1-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 57.2 MB/s
# Collecting transformers>=4.4.0
#   Downloading transformers-4.22.2-py3-none-any.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 47.9 MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from happytransformer) (3.17.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.6.0->happytransformer) (2022.8.2)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.6.0->happytransformer) (1.21.6)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.6.0->happytransformer) (0.3.5.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 57.0 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.6.0->happytransformer) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets>=1.6.0->happytransformer) (1.3.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets>=1.6.0->happytransformer) (3.8.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets>=1.6.0->happytransformer) (4.12.0)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.10.0-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 61.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets>=1.6.0->happytransformer) (21.3)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.6.0->happytransformer) (6.0.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 51.1 MB/s
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.6.0->happytransformer) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.6.0->happytransformer) (1.3.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.6.0->happytransformer) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.6.0->happytransformer) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.6.0->happytransformer) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.6.0->happytransformer) (4.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.6.0->happytransformer) (4.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.6.0->happytransformer) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.6.0->happytransformer) (22.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.6.0->happytransformer) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.6.0->happytransformer) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets>=1.6.0->happytransformer) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.6.0->happytransformer) (1.24.3)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 51.6 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 45.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.4.0->happytransformer) (2022.6.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets>=1.6.0->happytransformer) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.6.0->happytransformer) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.6.0->happytransformer) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets>=1.6.0->happytransformer) (1.15.0)
# Installing collected packages: urllib3, xxhash, tokenizers, responses, multiprocess, huggingface-hub, transformers, sentencepiece, datasets, happytransformer
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.5.1 happytransformer-2.4.1 huggingface-hub-0.10.0 multiprocess-0.70.13 responses-0.18.0 sentencepiece-0.1.97 tokenizers-0.12.1 transformers-4.22.2 urllib3-1.25.11 xxhash-3.0.0

# %%
from happytransformer import HappyTextToText

happy_tt = HappyTextToText("T5", "google/mt5-base")
# Out:
# Downloading:   0%|          | 0.00/702 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/376 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/convert_slow_tokenizer.py:447: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   "The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option"

# %%
happy_tt = HappyTextToText("T5", "google/mt5-base")

result = happy_tt.generate_text("grammar: இதன் காரணமாக பெரிய நகரங்கள் வெள்ளம் ஏற்படுகிறது.", args=beam_settings)
print(result.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8a9a7f629ec1> in <module>
#       1 happy_tt = HappyTextToText("T5", "google/mt5-base")
#       2
# ----> 3 result = happy_tt.generate_text("grammar: இதன் காரணமாக பெரிய நகரங்கள் வெள்ளம் ஏற்படுகிறது.", args=beam_settings)
#       4 print(result.text)
#
# NameError: name 'beam_settings' is not defined

# %%
from datasets import load_dataset

# %%
train_dataset = load_dataset("jfleg", split='validation[:]')

eval_dataset = load_dataset("jfleg", split='test[:]')

# %%
for case in train_dataset["corrections"][:2]:
  print(case)
  print(case[0])
  print("--------------------------------------------------------")

# %%
import csv

def generate_csv(csv_path, dataset):
    with open(csv_path, 'w', newline='') as csvfile:
        writter = csv.writer(csvfile)
        writter.writerow(["input", "target"])
        for case in dataset:
     	    # Adding the task's prefix to input 
            input_text = "grammar: " + case["sentence"]
            for correction in case["corrections"]:
                # a few of the cases contain blank strings. 
                if input_text and correction:
                    writter.writerow([input_text, correction])
                    


generate_csv("train.csv", train_dataset)
generate_csv("eval.csv", eval_dataset)

# %%
import pandas as pd
df=pd.read_csv('/content/grammar_train.csv')
lst=[]
for i in df['correctgrammar']:
  lst.append(i)
print(lst)       

lst2=[]
for i in df['wronggrammar']:
  input_text = "grammar: " + str(i)
  lst2.append(input_text)

data = {'input': lst2, 'target': lst}  
  
# Create DataFrame  
df1 = pd.DataFrame(data)  
  
# Print the output.  
df1.to_csv('train.csv')
df1
# Out:
# ['சேவையின் கண்ணியத்தைப் பாதுகாக்க பொருத்தமான அலுவலக உடைகள் அனுமதிக்கப்பட வேண்டும்.', 'தெற்கு பால்டிக் கடலில் உள்ள டேனிஷ் தீவு போர்ன்ஹோல்ம் அருகே இரண்டு குழாய்கள் சேதமடைந்தன.', 'தெற்கு பால்டிக் கடலில் உள்ள டேனிஷ் தீவு போர்ன்ஹோல்ம் அருகே இரண்டு குழாய்கள் சேதமடைந்தன.', 'வீட்டின் அலமாரியில் இருந்த எழுபது பவுனுக்கும் அதிகமான தங்கம் மற்றும் யூரோக்களை திருடர்கள் திருடிச் சென்றுள்ளனர்.', 'வீட்டின் அலமாரியில் இருந்த எழுபது பவுனுக்கும் அதிகமான தங்கம் மற்றும் யூரோக்களை திருடர்கள் திருடிச் சென்றுள்ளனர்.', 'திலீபனின் நினைவுத் தூபி அரச நிதியில் அமைக்கப்பட்டது எனத் தெரிவிக்கப்பட்டிருந்தது.', 'திலீபனின் நினைவுத் தூபி அரச நிதியில் அமைக்கப்பட்டது எனத் தெரிவிக்கப்பட்டிருந்தது.', 'நீருக்காக குளங்களை நாடிச் செல்லும் ஆடு, மாடுகள் உள்ளிட்ட கால்நடைகள் முதலைகளுக்கு இரையாகிறது.', 'இதை உரிய அதிகாரிகள் கவனத்தில் எடுக்க வேண்டும் என மக்கள் கோரிக்கை விடுகின்றனர்.', 'நவராத்திரியின் முதல் மூன்று நாட்கள் வீரத்தை அருளும் துர்க்கை அம்மனின் வடிவத்தை நோக்கி விரதம் அனுஷ்டிக்கப்படுகிறது.', 'நவராத்திரியின் முதல் மூன்று நாட்கள் வீரத்தை அருளும் துர்க்கை அம்மனின் வடிவத்தை நோக்கி விரதம் அனுஷ்டிக்கப்படுகிறது.', 'ஏழை விறகுவெட்டி ஒருவன் தன் மனைவியுடன் வாழ்ந்து வந்தான்.', 'ஒரு நாள் இரவு அவனுடைய மகன்கள் தூங்கிக் கொண்டிருந்தனர்.', 'நாம் எவ்வளவு காலம் துன்பப்படுவது?', 'நீண்ட தூரம் நடந்து காட்டின் நடுப்பகுதிக்கு வந்தார்கள்.', 'காற்று அடிக்கும் போதெல்லாம் மரத்தில் அது மோதியது.', 'சில சமயம் மான் போன்ற சற்றுப் பெரிய விலங்குகளைக் கூடத் தாக்கும்.', 'குறட்டியின் வாயில் நீர் சுரந்தது.', 'எதிர்பாராத தாக்குதலால் நிலைகுலைந்து போனது. ', 'ஓர் ஊரில் பெண் ஒருத்தி இருந்தாள்.', 'அவள் கணவன் வணிகத்திற்காக வெளியூர் சென்றிருந்தான்.', 'ஆபத்து வரப் போவதை மாடுகள் உணர்ந்தன.', 'சிறிது தூரத்தல் பயங்கரமான புலி ஒன்று வந்து கொண்டிருந்தது.', 'இதைக் கேட்ட நரியால் சிரிப்பை அடக்க முடியவில்லை.', 'இதைக் கேட்ட நரியால் சிரிப்பை அடக்க முடியவில்லை.', 'நாம் அங்கே செல்வோம்.', 'நாம் அங்கே செல்
ும் மனித கலாச்சாரம் எல்லோராலும் ஊக்குவிக்க படுகிறது.', 'இதன் காரணமாகவே மாற்று வழிகளை கையாளும் மனித கலாச்சாரம் எல்லோராலும் ஊக்குவிக்க படுகிறது.', 'இதற்க்கு தேர்வு காணுவதே இன்றைய நாடுகளுக்கு முதல் கடமையாகும்.', 'இதற்க்கு தேர்வு காணுவதே இன்றைய நாடுகளுக்கு முதல் கடமையாகும்', 'திருக்குறளுக்கு அடுத்தபடியாக அதிகம் மொழி பெயர்க்கப்பட் ...
#                                                 input  \
# 0   grammar: சேவையால் கண்ணியத்தைப் பாதுகாக்க பொருத...
# 1   grammar: தெற்கு பால்டிக் கடலில் உள்ள டேனிஷ் தீ...
# 2   grammar: தெற்கு பால்டிக் கடலில் உள்ள டேனிஷ் தீ...
# 3   grammar: வீட்டின் அலமாரியில் இருந்த எழுபது பவு...
# 4   grammar: வீட்டின் அலமாரியில் இருந்த எழுபது பவு...
# ..                                                ...
# 68  grammar: இந்த நிகழ்வுக்கு பிறகுதான் பாரதி என்ற...
# 69  grammar: தனது கவித்திறமை சுதந்திர போராட்டம் சா...
# 70  grammar: தனது கவித்திறமையில் சுதந்திர போராட்டம...
# 71  grammar: அவர்கள் நடத்திய சுதேசி போராட்டங்கள் த...
# 72  grammar: அவர்கள் நடத்திய சுதேசி போராட்டங்களில்...
#
#                                                target
# 0   சேவையின் கண்ணியத்தைப் பாதுகாக்க பொருத்தமான அலு...
# 1   தெற்கு பால்டிக் கடலில் உள்ள டேனிஷ் தீவு போர்ன்...
# 2   தெற்கு பால்டிக் கடலில் உள்ள டேனிஷ் தீவு போர்ன்...
# 3   வீட்டின் அலமாரியில் இருந்த எழுபது பவுனுக்கும் ...
# 4   வீட்டின் அலமாரியில் இருந்த எழுபது பவுனுக்கும் ...
# ..                                                ...
# 68  இந்த நிகழ்வுக்கு பிறகுதான் பாரதி என்ற புனை பெய...
# 69  தனது கவித்திறமையால் சுதந்திர போராட்டம் சார்ந்த...
# 70  தனது கவித்திறமையால் சுதந்திர போராட்டம் சார்ந்த...
# 71  அவர்கள் நடத்திய சுதேசி போராட்டங்களில் தமது கரு...
# 72  அவர்கள் நடத்திய சுதேசி போராட்டங்களில் தமது கரு...
#
# [73 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv('/content/grammer_test.csv')
lst=[]
for i in df['output']:
  lst.append(i)
print(lst)       

lst2=[]
for i in df['input']:
  input_text = "grammar: " + str(i)
  lst2.append(input_text)


data1 = {'input': lst2, 'target': lst}  
  
# Create DataFrame  
df2 = pd.DataFrame(data1)  
  
# Print the output.  
df2.to_csv('test.csv')
df2
# Out:
# 7   ஆண் வாரிசு இல்லாத அரசுகளை கம்பெனி வசம் ஒப்படைக...
# 8   ஆண் வாரிசு இல்லாத அரசுகளை கம்பெனி வசம் ஒப்படைக...
# 9   ஆண் வாரிசு இல்லாத அரசுகளை கம்பெனி வசம் ஒப்படைக...
# 10  அத்துடன் ஆங்கிலேய அரசுக்கு எதிராக போருக்கும் த...
# 11  அத்துடன் ஆங்கிலேய அரசுக்கு எதிராக போருக்கும் த...
# 12  அத்துடன் ஆங்கிலேய அரசுக்கு எதிராக போருக்கும் த...
# 13  அங்கு தன்னை காட்டிக்கொடுக்காது மரணத்தை தழுவிய ...
# 14  அங்கு தன்னை காட்டிக்கொடுக்காது மரணத்தை தழுவிய ...
# 15  அந்த இடம் கொல்லங்குடி வெட்டுடையகாளியம்மன் கோயி...
# 16  அந்த இடம் கொல்லங்குடி வெட்டுடையகாளியம்மன் கோயி...
# 17  குயிலி இந்திய வரலாற்றில் முதல் தற்கொலை படை தாக...
# 18  குயிலி இந்திய வரலாற்றில் முதல் தற்கொலை படை தாக...
# 19  புவியின் நன்னீர் சுழற்சிக்கு மழையே உறுதுணையாக ...
# 20  இவ்வகை மழை மதிய நேரங்கள் மற்றும் சாயங்கால வேலை...
# 21  மேகாலயா மாநிலத்தில் உள்ள சிரபுஞ்சி மாவட்டத்தில...
# 22  புயல் மற்றும் சூறாவளி ஏற்படும்போது உடன் பெய்யு...
# 23  சூறாவளி இந்திய எல்லையில் அதிகம் வராமல் இருந்த ...
# 24  சூறாவளி இந்திய எல்லையில் அதிகம் வராமல் இருந்த ...
# 25  இதன் காரணமாக பெரிய நகரங்களில் வெள்ளம் ஏற்படுகி...

# %%
 before_result = happy_tt.eval("/content/test.csv")
# Out:
# WARNING:datasets.builder:Using custom data configuration default-30c148fab1dd2723
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-30c148fab1dd2723/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-30c148fab1dd2723/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3543: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   "`as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your "
# The following columns in the evaluation set don't have a corresponding argument in `MT5ForConditionalGeneration.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `MT5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 26
#   Batch size = 1
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='26' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26/26 00:00]
#     </div>

# %%
print("Before loss:", before_result.loss)
# Out:
# Before loss: 10.759313583374023

# %%
from happytransformer import TTTrainArgs

args = TTTrainArgs(batch_size=1,num_train_epochs=10)
happy_tt.train("train.csv", args=args)
# Out:
# WARNING:datasets.builder:Using custom data configuration default-e0632df37040a3c7
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-e0632df37040a3c7/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-e0632df37040a3c7/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# PyTorch: setting up devices
# The following columns in the training set don't have a corresponding argument in `MT5ForConditionalGeneration.forward` and have been ignored: Unnamed: 0. If Unnamed: 0 are not expected by `MT5ForConditionalGeneration.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 73
#   Num Epochs = 10
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 730
#     <div>
#
#       <progress value='667' max='730' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [667/730 03:50 < 00:21, 2.89 it/s, Epoch 9.12/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>4.926900</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
before_loss = happy_tt.eval("test.csv")

print("After loss: ", before_loss.loss)

# %%
from happytransformer import TTSettings

beam_settings =  TTSettings(num_beams=5, min_length=1, max_length=25)

# %%
model=happy_tt

# %%
example_1 = "grammar: சேவையால் கண்ணியத்தைப் பாதுகாக்க பொருத்தமான அலுவலக உடைகள் அனுமதிக்கப்பட வேண்டும்."
result_1 = model.generate_text(example_1, args=beam_settings)
print(result_1)
